# %% [markdown]
# This Jupyter file includes the link prediction results of MaskGAE under the dot-product probing (DPP) setting. The results in Table 2 can be seen after `AUC    Final Test:` and `AP    Final Test:` at the end of the output.
#
# Note that this file is only for result presentation. Commands below are not directly executable.

# %% [markdown]
# ## MaskGAE (path)

# %%
# !python train_linkpred_dp.py --dataset Cora --bn
# Out:
# +--------------------+--------+
# |     Parameter      | Value  |
# +====================+========+
# | alpha              | 0.003  |
# +--------------------+--------+
# | batch_size         | 65536  |
# +--------------------+--------+
# | bn                 | True   |
# +--------------------+--------+
# | dataset            | Cora   |
# +--------------------+--------+
# | debug              | False  |
# +--------------------+--------+
# | decoder_channels   | 64     |
# +--------------------+--------+
# | decoder_dropout    | 0.200  |
# +--------------------+--------+
# | decoder_layers     | 2      |
# +--------------------+--------+
# | device             | 0      |
# +--------------------+--------+
# | encoder_activation | elu    |
# +--------------------+--------+
# | encoder_channels   | 128    |
# +--------------------+--------+
# | encoder_dropout    | 0.800  |
# +--------------------+--------+
# | encoder_layers     | 1      |
# +--------------------+--------+
# ...

# %%
# !python train_linkpred_dp.py --dataset Citeseer --bn
# Out:
# +--------------------+----------+
# |     Parameter      |  Value   |
# +====================+==========+
# | alpha              | 0.003    |
# +--------------------+----------+
# | batch_size         | 65536    |
# +--------------------+----------+
# | bn                 | True     |
# +--------------------+----------+
# | dataset            | Citeseer |
# +--------------------+----------+
# | debug              | False    |
# +--------------------+----------+
# | decoder_channels   | 64       |
# +--------------------+----------+
# | decoder_dropout    | 0.200    |
# +--------------------+----------+
# | decoder_layers     | 2        |
# +--------------------+----------+
# | device             | 0        |
# +--------------------+----------+
# | encoder_activation | elu      |
# +--------------------+----------+
# | encoder_channels   | 128      |
# +--------------------+----------+
# | encoder_dropout    | 0.800    |
# +--------------------+----------+
# ...

# %%
# !python train_linkpred_dp.py --dataset Pubmed --bn --encoder_dropout 0.2
# Out:
# +--------------------+--------+
# |     Parameter      | Value  |
# +====================+========+
# | alpha              | 0.003  |
# +--------------------+--------+
# | batch_size         | 65536  |
# +--------------------+--------+
# | bn                 | True   |
# +--------------------+--------+
# | dataset            | Pubmed |
# +--------------------+--------+
# | debug              | False  |
# +--------------------+--------+
# | decoder_channels   | 64     |
# +--------------------+--------+
# | decoder_dropout    | 0.200  |
# +--------------------+--------+
# | decoder_layers     | 2      |
# +--------------------+--------+
# | device             | 0      |
# +--------------------+--------+
# | encoder_activation | elu    |
# +--------------------+--------+
# | encoder_channels   | 128    |
# +--------------------+--------+
# | encoder_dropout    | 0.200  |
# +--------------------+--------+
# | encoder_layers     | 1      |
# +--------------------+--------+
# ...

# %% [markdown]
# ## MaskGAE (edge)

# %%
# !python train_linkpred_dp.py --dataset Cora --bn --mask Edge
# Out:
# +--------------------+--------+
# |     Parameter      | Value  |
# +====================+========+
# | alpha              | 0.003  |
# +--------------------+--------+
# | batch_size         | 65536  |
# +--------------------+--------+
# | bn                 | True   |
# +--------------------+--------+
# | dataset            | Cora   |
# +--------------------+--------+
# | debug              | False  |
# +--------------------+--------+
# | decoder_channels   | 64     |
# +--------------------+--------+
# | decoder_dropout    | 0.200  |
# +--------------------+--------+
# | decoder_layers     | 2      |
# +--------------------+--------+
# | device             | 0      |
# +--------------------+--------+
# | encoder_activation | elu    |
# +--------------------+--------+
# | encoder_channels   | 128    |
# +--------------------+--------+
# | encoder_dropout    | 0.800  |
# +--------------------+--------+
# | encoder_layers     | 1      |
# +--------------------+--------+
# ...

# %%
# !python train_linkpred_dp.py --dataset Citeseer --bn --mask Edge
# Out:
# +--------------------+----------+
# |     Parameter      |  Value   |
# +====================+==========+
# | alpha              | 0.003    |
# +--------------------+----------+
# | batch_size         | 65536    |
# +--------------------+----------+
# | bn                 | True     |
# +--------------------+----------+
# | dataset            | Citeseer |
# +--------------------+----------+
# | debug              | False    |
# +--------------------+----------+
# | decoder_channels   | 64       |
# +--------------------+----------+
# | decoder_dropout    | 0.200    |
# +--------------------+----------+
# | decoder_layers     | 2        |
# +--------------------+----------+
# | device             | 0        |
# +--------------------+----------+
# | encoder_activation | elu      |
# +--------------------+----------+
# | encoder_channels   | 128      |
# +--------------------+----------+
# | encoder_dropout    | 0.800    |
# +--------------------+----------+
# ...

# %%
# !python train_linkpred_dp.py --dataset Pubmed --bn --encoder_dropout 0.2 --mask Edge
# Out:
# +--------------------+--------+
# |     Parameter      | Value  |
# +====================+========+
# | alpha              | 0.003  |
# +--------------------+--------+
# | batch_size         | 65536  |
# +--------------------+--------+
# | bn                 | True   |
# +--------------------+--------+
# | dataset            | Pubmed |
# +--------------------+--------+
# | debug              | False  |
# +--------------------+--------+
# | decoder_channels   | 64     |
# +--------------------+--------+
# | decoder_dropout    | 0.200  |
# +--------------------+--------+
# | decoder_layers     | 2      |
# +--------------------+--------+
# | device             | 0      |
# +--------------------+--------+
# | encoder_activation | elu    |
# +--------------------+--------+
# | encoder_channels   | 128    |
# +--------------------+--------+
# | encoder_dropout    | 0.200  |
# +--------------------+--------+
# | encoder_layers     | 1      |
# +--------------------+--------+
# ...
